# %% [markdown]
# ## Refer the loadData.ipynb to see how is data prepared before training

# %%
## all training are done on kaggle
# using T4 GPU

# the dataset generated are uploaded to kaggle input directory to use
# datasets/RCNN_YOLO_SET is uploaded as mvtec-screws/RCNN_YOLO_SET in kaggle

# the three annotations added with segmentation attributes:
#  - mvtec_screws_val_with_seg.json
#  - mvtec_screws_train_with_seg.json
#  - mvtec_screws_test_with_seg.json
# is in the coco-screw-with-seg dataset in kaggle input of the mask_rcnn training notebook

# %% [markdown]
# ## Pre-requisite
#
# - join the kaggle group by clicking the link below
# - you may need to have a kaggle account first
#
# https://www.kaggle.com/groups/imageasg/pending-invite/67CCC9AC-AB2B-4231-8BE2-5AA58AF024ED

# %% [markdown]
# ## Under the group shared resources, you may see:
#
# ### Training notebooks
# - MRCNN
# - FASTER_RCNN
# - yolo8_obb
# - yolo11_obb
# - yolo11-coin-added - trained again with coined to measure length of the screw
#
# ### results
# - Results
#
# ### datasets
# - MVTEC-SCREWS
# - COCO_screw_with_seg
